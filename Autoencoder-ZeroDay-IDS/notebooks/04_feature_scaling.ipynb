# %%
X_train_scaled.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 X_train_scaled.describe()
#
# NameError: name 'X_train_scaled' is not defined

# %%
X_train_scaled.head()
# Out:
#         dur     proto   service     state     spkts     dpkts    sbytes  \
# 0 -0.213727  0.410563 -0.674406  0.932695 -0.124455 -0.151816 -0.043684
# 1 -0.213728  0.410563 -0.674406  0.932695 -0.124455 -0.151816 -0.036308
# 2 -0.213729  0.410563 -0.674406  0.932695 -0.124455 -0.151816 -0.040351
# 3 -0.213729  0.410563 -0.674406  0.932695 -0.124455 -0.151816 -0.041330
# 4 -0.213728  0.410563 -0.674406  0.932695 -0.124455 -0.151816 -0.034187
#
#      dbytes      rate     sttl  ...  ct_dst_ltm  ct_src_dport_ltm  \
# 0 -0.087369  0.057181  0.71944  ...   -0.563660         -0.468312
# 1 -0.087369  0.286565  0.71944  ...   -0.563660         -0.468312
# 2 -0.087369  0.791209  0.71944  ...   -0.563660         -0.468312
# 3 -0.087369  0.566923  0.71944  ...   -0.444868         -0.349115
# 4 -0.087369  0.118350  0.71944  ...   -0.444868         -0.349115
#
#    ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0         -0.450186       -0.477994     -0.090857   -0.090617
# 1         -0.450186       -0.477994     -0.090857   -0.090617
# 2         -0.450186       -0.390391     -0.090857   -0.090617
# 3         -0.450186       -0.390391     -0.090857   -0.090617
# 4         -0.450186       -0.390391     -0.090857   -0.090617
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports
# 0         -0.203143   -0.640033   -0.644190         -0.10607
# 1         -0.203143   -0.640033   -0.644190         -0.10607
# 2         -0.203143   -0.640033   -0.554273         -0.10607
# 3         -0.203143   -0.522990   -0.554273         -0.10607
# 4         -0.203143   -0.522990   -0.554273         -0.10607
#
# [5 rows x 42 columns]

# %%
X_train_scaled.to_csv("../dataset/processed/X_train_scaled.csv", index=False)
X_test_scaled.to_csv("../dataset/processed/X_test_scaled.csv", index=False)

y_train.to_csv("../dataset/processed/y_train.csv", index=False)
y_test.to_csv("../dataset/processed/y_test.csv", index=False)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=X_train.columns
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=X_test.columns
)

# %%
joblib.dump(scaler, "../scaler/standard_scaler.pkl")
# Out:
# ['../scaler/standard_scaler.pkl']

# %%
from sklearn.preprocessing import StandardScaler
import joblib

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train.select_dtypes(include="object").columns
# Out:
# Index([], dtype='str')

# %%
X_train = train_df.drop(["label", "attack_cat"], axis=1)
y_train = train_df["label"]

X_test = test_df.drop(["label", "attack_cat"], axis=1)
y_test = test_df["label"]

# %%
import pandas as pd

train_df = pd.read_csv("../dataset/processed/train_encoded.csv")
test_df = pd.read_csv("../dataset/processed/test_encoded.csv")

# %%
X_train.select_dtypes(include="object").columns
# Out:
# C:\Users\Sonakshi\AppData\Local\Temp\ipykernel_14868\981028811.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   X_train.select_dtypes(include="object").columns
# Index(['proto', 'service', 'state'], dtype='str')

# %%
X_train = train_df.drop(["label", "attack_cat"], axis=1)
y_train = train_df["label"]

X_test = test_df.drop(["label", "attack_cat"], axis=1)
y_test = test_df["label"]

# %%
X_train.select_dtypes(include="object").columns
# Out:
# C:\Users\Sonakshi\AppData\Local\Temp\ipykernel_14868\981028811.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   X_train.select_dtypes(include="object").columns
# Index(['proto', 'service', 'state'], dtype='str')

# %%
print(X_train.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 82332 entries, 0 to 82331
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 82332 non-null  int64
#  1   dur                82332 non-null  float64
#  2   proto              82332 non-null  str
#  3   service            82332 non-null  str
#  4   state              82332 non-null  str
#  5   spkts              82332 non-null  int64
#  6   dpkts              82332 non-null  int64
#  7   sbytes             82332 non-null  int64
#  8   dbytes             82332 non-null  int64
#  9   rate               82332 non-null  float64
#  10  sttl               82332 non-null  int64
#  11  dttl               82332 non-null  int64
#  12  sload              82332 non-null  float64
#  13  dload              82332 non-null  float64
#  14  sloss              82332 non-null  int64
#  15  dloss              82332 non-null  int64
#  16  sinpkt             82332 non-null  float64
#  17  dinpkt             82332 non-null  float64
#  18  sjit               82332 non-null  float64
#  19  djit               82332 non-null  float64
#  20  swin               82332 non-null  int64
#  21  stcpb              82332 non-null  int64
#  22  dtcpb              82332 non-null  int64
#  23  dwin               82332 non-null  int64
#  24  tcprtt             82332 non-null  float64
#  25  synack             82332 non-null  float64
#  26  ackdat             82332 non-null  float64
#  27  smean              82332 non-null  int64
#  28  dmean              82332 non-null  int64
#  29  trans_depth        82332 non-null  int64
#  30  response_body_len  82332 non-null  int64
#  31  ct_srv_src         82332 non-null  int64
#  32  ct_state_ttl       82332 non-null  int64
#  33  ct_dst_ltm         82332 non-null  int64
#  34  ct_src_dport_ltm   82332 non-null  int64
#  35  ct_dst_sport_ltm   82332 non-null  int64
#  36  ct_dst_src_ltm     82332 non-null  int64
#  37  is_ftp_login       82332 non-null  int64
#  38  ct_ftp_cmd         82332 non-null  int64
#  39  ct_flw_http_mthd   82332 non-null  int64
#  40  ct_src_ltm         82332 non-null  int64
#  41  ct_srv_dst         82332 non-null  int64
#  42  is_sm_ips_ports    82332 non-null  int64
# dtypes: float64(11), int64(29), str(3)
# memory usage: 27.7 MB
# None

# %%
print(X_train[['proto','service','state']].head())
# Out:
#   proto service state
# 0   udp       -   INT
# 1   udp       -   INT
# 2   udp       -   INT
# 3   udp       -   INT
# 4   udp       -   INT

# %%
X_train.head()
X_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 82332 entries, 0 to 82331
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 82332 non-null  int64
#  1   dur                82332 non-null  float64
#  2   proto              82332 non-null  str
#  3   service            82332 non-null  str
#  4   state              82332 non-null  str
#  5   spkts              82332 non-null  int64
#  6   dpkts              82332 non-null  int64
#  7   sbytes             82332 non-null  int64
#  8   dbytes             82332 non-null  int64
#  9   rate               82332 non-null  float64
#  10  sttl               82332 non-null  int64
#  11  dttl               82332 non-null  int64
#  12  sload              82332 non-null  float64
#  13  dload              82332 non-null  float64
#  14  sloss              82332 non-null  int64
#  15  dloss              82332 non-null  int64
#  16  sinpkt             82332 non-null  float64
#  17  dinpkt             82332 non-null  float64
#  18  sjit               82332 non-null  float64
#  19  djit               82332 non-null  float64
#  20  swin               82332 non-null  int64
#  21  stcpb              82332 non-null  int64
#  22  dtcpb              82332 non-null  int64
#  23  dwin               82332 non-null  int64
#  24  tcprtt             82332 non-null  float64
#  25  synack             82332 non-null  float64
#  26  ackdat             82332 non-null  float64
#  27  smean              82332 non-null  int64
#  28  dmean              82332 non-null  int64
#  29  trans_depth        82332 non-null  int64
#  30  response_body_len  82332 non-null  int64
#  31  ct_srv_src         82332 non-null  int64
#  32  ct_state_ttl       82332 non-null  int64
#  33  ct_dst_ltm         82332 non-null  int64
#  34  ct_src_dport_ltm   82332 non-null  int64
#  35  ct_dst_sport_ltm   82332 non-null  int64
#  36  ct_dst_src_ltm     82332 non-null  int64
#  37  is_ftp_login       82332 non-null  int64
#  38  ct_ftp_cmd         82332 non-null  int64
#  39  ct_flw_http_mthd   82332 non-null  int64
#  40  ct_src_ltm         82332 non-null  int64
#  41  ct_srv_dst         82332 non-null  int64
#  42  is_sm_ips_ports    82332 non-null  int64
# dtypes: float64(11), int64(29), str(3)
# memory usage: 27.7 MB

# %%
print(X_train.select_dtypes(include="object").columns)
# Out:
# Index(['proto', 'service', 'state'], dtype='str')
# C:\Users\Sonakshi\AppData\Local\Temp\ipykernel_14868\2453056806.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   print(X_train.select_dtypes(include="object").columns)

# %%
print(X_train.dtypes)
# Out:
# id                     int64
# dur                  float64
# proto                    str
# service                  str
# state                    str
# spkts                  int64
# dpkts                  int64
# sbytes                 int64
# dbytes                 int64
# rate                 float64
# sttl                   int64
# dttl                   int64
# sload                float64
# dload                float64
# sloss                  int64
# dloss                  int64
# sinpkt               float64
# dinpkt               float64
# sjit                 float64
# djit                 float64
# swin                   int64
# stcpb                  int64
# dtcpb                  int64
# dwin                   int64
# tcprtt               float64
# synack               float64
# ackdat               float64
# smean                  int64
# dmean                  int64
# trans_depth            int64
# response_body_len      int64
# ct_srv_src             int64
# ct_state_ttl           int64
# ct_dst_ltm             int64
# ct_src_dport_ltm       int64
# ct_dst_sport_ltm       int64
# ct_dst_src_ltm         int64
# is_ftp_login           int64
# ct_ftp_cmd             int64
# ct_flw_http_mthd       int64
# ct_src_ltm             int64
# ct_srv_dst             int64
# is_sm_ips_ports        int64
# dtype: object

# %%
X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 X_train_scaled = scaler.fit_transform(X_train)
#       2
#       3 X_test_scaled = scaler.transform(X_test)
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\base.py:969, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     954         warnings.warn(
#     955             (
#     956                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    964             UserWarning,
#     965         )
#     967 if y is None:
#     968     # fit method of arity 1 (unsupervised transformation)
# --> 969     return self.fit(X, **fit_params).transform(X)
#     970 else:
#     971     # fit method of arity 2 (supervised transformation)
#     972     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\preprocessing\_data.py:928, in StandardScaler.fit(self, X, y, sample_weight)
#     926 # Reset internal state before fitting
#     927 self._reset()
# --> 928 return self.partial_fit(X, y, sample_weight)
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\preprocessing\_data.py:965, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     963 xp, _, X_device = get_namespace_and_device(X)
#     964 first_call = not hasattr(self, "n_samples_seen_")
# --> 965 X = validate_data(
#     966     self,
#     967     X,
#     968     accept_sparse=("csr", "csc"),
#     969     dtype=supported_float_dtypes(xp, X_device),
#     970     ensure_all_finite="allow-nan",
#     971     reset=first_call,
#     972 )
#     973 n_features = X.shape[1]
#     975 callback_ctx = self._init_callback_context()
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\utils\validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\utils\validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033         array = xp.astype(array, dtype, copy=False)
#    1034     else:
# -> 1035         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1036 except ComplexWarning as complex_warning:
#    1037     raise ValueError(
#    1038         "Complex data not supported\n{}\n".format(array)
#    1039     ) from complex_warning
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\sklearn\utils\_array_api.py:976, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     974     array = numpy.array(array, order=order, dtype=dtype)
#     975 else:
# --> 976     array = numpy.asarray(array, order=order, dtype=dtype)
#     978 # At this point array is a NumPy ndarray. We convert it to an array
#     979 # container that is consistent with the input's namespace.
#     980 return xp.asarray(array)
#
# File c:\Users\Sonakshi\Desktop\Autoencoder-ZeroDay-IDS\venv\Lib\site-packages\pandas\core\generic.py:2039, in NDFrame.__array__(self, dtype, copy)
#    2035             )
#    2036         values = self._values
#    2037         if copy is None:
#    2038             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2039             arr = np.asarray(values, dtype=dtype)
#    2040         else:
#    2041             arr = np.array(values, dtype=dtype, copy=copy)
#    2042
#
# ValueError: could not convert string to float: 'udp'

# %%
scaler = StandardScaler()

# %%
train_df.columns
X_train = train_df.drop(columns=["label", "attack_cat"])

X_test = test_df.drop(columns=["label", "attack_cat"])
print(X_train.shape)

print(X_test.shape)
# Out:
# (82332, 43)
# (175341, 43)

# %%
train_df = pd.read_csv("../dataset/processed/train_encoded.csv")
test_df = pd.read_csv("../dataset/processed/test_encoded.csv")

print(train_df.shape)
print(test_df.shape)
# Out:
# (82332, 44)
# (175341, 44)

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
import joblib

# %%
print(train_df.dtypes)
# Out:
# dur                  float64
# proto                float64
# service              float64
# state                float64
# spkts                  int64
# dpkts                  int64
# sbytes                 int64
# dbytes                 int64
# rate                 float64
# sttl                   int64
# dttl                   int64
# sload                float64
# dload                float64
# sloss                  int64
# dloss                  int64
# sinpkt               float64
# dinpkt               float64
# sjit                 float64
# djit                 float64
# swin                   int64
# stcpb                  int64
# dtcpb                  int64
# dwin                   int64
# tcprtt               float64
# synack               float64
# ackdat               float64
# smean                  int64
# dmean                  int64
# trans_depth            int64
# response_body_len      int64
# ct_srv_src             int64
# ct_state_ttl           int64
# ct_dst_ltm             int64
# ct_src_dport_ltm       int64
# ct_dst_sport_ltm       int64
# ct_dst_src_ltm         int64
# is_ftp_login           int64
# ct_ftp_cmd             int64
# ct_flw_http_mthd       int64
# ct_src_ltm             int64
# ct_srv_dst             int64
# is_sm_ips_ports        int64
# attack_cat               str
# label                  int64
# dtype: object

# %%
X_train = train_df.drop(columns=["label", "attack_cat"])
y_train = train_df["label"]

X_test = test_df.drop(columns=["label", "attack_cat"])
y_test = test_df["label"]

print(X_train.shape)
print(X_test.shape)
# Out:
# (82332, 42)
# (175341, 42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=X_train.columns
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=X_test.columns
)

# %%
X_train_scaled.to_csv("../dataset/processed/X_train_scaled.csv", index=False)
X_test_scaled.to_csv("../dataset/processed/X_test_scaled.csv", index=False)

y_train.to_csv("../dataset/processed/y_train.csv", index=False)
y_test.to_csv("../dataset/processed/y_test.csv", index=False)

print("All files saved successfully!")
# Out:
# All files saved successfully!

# %%
import pandas as pd
import joblib

# Load scaler
scaler = joblib.load("../scaler/standard_scaler.pkl")

# Load normal training data
X_train_normal = pd.read_csv("../dataset/processed/X_train_normal.csv")

# Scale it
X_train_normal_scaled = scaler.transform(X_train_normal)

# Convert back to DataFrame
X_train_normal_scaled = pd.DataFrame(
    X_train_normal_scaled,
    columns=X_train_normal.columns
)

# Save it
X_train_normal_scaled.to_csv(
    "../dataset/processed/X_train_normal_scaled.csv",
    index=False
)

print(X_train_normal_scaled.shape)
# Out:
# (37000, 42)
